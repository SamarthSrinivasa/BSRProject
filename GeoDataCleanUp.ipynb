# %%
import pandas
import geopandas
import matplotlib.pyplot as plt

# %%
LAcity = geopandas.read_file("/Users/samarthsrinivasa/Downloads/DS-Path/Pyneapple-main/notebooks/data/LACity") #LA City, 1012
LAcounty = geopandas.read_file("/Users/samarthsrinivasa/Downloads/DS-Path/Pyneapple-main/notebooks/data/LACounty") #LA County, 2344
SCA = geopandas.read_file("/Users/samarthsrinivasa/Downloads/DS-Path/Pyneapple-main/notebooks/data/SCA") #SCA, 3947
Diversity = geopandas.read_file("/Users/samarthsrinivasa/Downloads/DS-Path/PRUC-master-Yongyi-Liu/DataFile/diversity") #Diversity, 3225
#10528? 167 extra rows were created 
#LA City = 1012 x 67
#LA county = 2344 x 54
#SCA = 3947 x 80

LAcounty
# Out:
#          fid STATEFP10 COUNTYFP10 TRACTCE10      GEOID10   NAME10  \
# 0        1.0        06        037    920336  06037920336  9203.36
# 1        2.0        06        037    920044  06037920044  9200.44
# 2        3.0        06        037    573003  06037573003  5730.03
# 3        4.0        06        037    571704  06037571704  5717.04
# 4        5.0        06        037    570403  06037570403  5704.03
# ...      ...       ...        ...       ...          ...      ...
# 2339  2342.0        06        037    430302  06037430302  4303.02
# 2340  2343.0        06        037    430723  06037430723  4307.23
# 2341  2344.0        06        037    431100  06037431100     4311
# 2342  2345.0        06        037    533603  06037533603  5336.03
# 2343  2346.0        06        037    534101  06037534101  5341.01
#
#                 NAMELSAD10 MTFCC10 FUNCSTAT10    ALAND10  ...  Tot_Housin  \
# 0     Census Tract 9203.36   G5020          S  1656848.0  ...      1839.0
# ...

# %%
SCA.info()
#LAcity.info()
#LAcounty.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3947 entries, 0 to 3946
# Data columns (total 80 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    3947 non-null   int64
#  1   GEOID10     3947 non-null   object
#  2   COUNTYFP10  3947 non-null   object
#  3   TRACTCE10   3947 non-null   object
#  4   Cnty_Name   3825 non-null   object
#  5   City_Name   3704 non-null   object
#  6   ZIP         3947 non-null   int64
#  7   Acres       3947 non-null   float64
#  8   SqMi        3947 non-null   float64
#  9   Pop_16      3947 non-null   int64
#  10  Pop_Den     3947 non-null   int64
#  11  Pop_Src     3947 non-null   object
#  12  Pop_10      3947 non-null   int64
#  13  White_Pct   3947 non-null   float64
#  14  Black_Pct   3947 non-null   float64
#  15  Asian_Pct   3947 non-null   float64
#  16  Latino_Pct  3947 non-null   float64
#  17  Mltpl_Pct   3947 non-null   float64
# ...

# %%
csv_filename = 'LAcity.csv'
LAcity.to_csv(csv_filename, index=False)

# %%
LAcity
# Out:
#          fid  OBJECTID TRACTCE10   POP  LATPOP_D  WHIPOP_D  BLAPOP_D  \
# 0        1.0         1    101110  4731      1324      2656        83
# 1        2.0         2    101122  3664       575      2437        34
# 2        3.0         3    101210  5990      2219      2890       192
# 3        4.0         4    101220  3363      1272      1662        45
# 4        5.0         5    101300  4199       503      3190        47
# ...      ...       ...       ...   ...       ...       ...       ...
# 1007  1008.0      1008    980024   186        23       135         4
# 1008  1009.0      1009    980026    20         1        17         1
# 1009  1010.0      1010    980028     4         2         0         2
# 1010  1011.0      1011    980031  1262       390       512       223
# 1011  1012.0      1012    990200     0         0         0         0
#
#       AMIPOP_D  ASIPOP_D  HPIPOP_D  ...  Tot_Housin  Occup_Hous  Vac_Housin  \
# ...

# %%
target_crs = 'EPSG:4326'  # Choose a CRS, such as WGS 84

LAcity_transformed = LAcity.to_crs(target_crs)
LAcounty_transformed = LAcounty.to_crs(target_crs)
SCA_transformed = SCA.to_crs(target_crs)
Diversity_transformed = Diversity.to_crs(target_crs)

# Concatenate the transformed GeoDataFrames
combined = geopandas.GeoDataFrame(pandas.concat([LAcity_transformed, LAcounty_transformed, SCA_transformed, Diversity_transformed], ignore_index=True))
combined
# Out:
#        fid  OBJECTID TRACTCE10     POP  LATPOP_D  WHIPOP_D  BLAPOP_D  \
# 0      1.0       1.0    101110  4731.0    1324.0    2656.0      83.0
# 1      2.0       2.0    101122  3664.0     575.0    2437.0      34.0
# 2      3.0       3.0    101210  5990.0    2219.0    2890.0     192.0
# 3      4.0       4.0    101220  3363.0    1272.0    1662.0      45.0
# 4      5.0       5.0    101300  4199.0     503.0    3190.0      47.0
# ...    ...       ...       ...     ...       ...       ...       ...
# 10523  NaN       NaN       NaN     NaN       NaN       NaN       NaN
# 10524  NaN       NaN       NaN     NaN       NaN       NaN       NaN
# 10525  NaN       NaN       NaN     NaN       NaN       NaN       NaN
# 10526  NaN       NaN       NaN     NaN       NaN       NaN       NaN
# 10527  NaN       NaN       NaN     NaN       NaN       NaN       NaN
#
#        AMIPOP_D  ASIPOP_D  HPIPOP_D  ...  count_q4_M  Diversity  BlackorA  \
# ...

# %%
csv_filename = 'CombinedDataSets.csv'
combined.to_csv(csv_filename, index=False)

# %%
csv_filename = 'LAcounty.csv'
LAcounty.to_csv(csv_filename, index=False)

# %%
csv_filename = 'SCA.csv'
SCA.to_csv(csv_filename, index=False)

# %%
csv_filename = 'Diversity.csv'
Diversity.to_csv(csv_filename, index=False)
